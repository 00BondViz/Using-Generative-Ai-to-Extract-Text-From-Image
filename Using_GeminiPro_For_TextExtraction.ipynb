# %% [markdown]
# <a href="https://colab.research.google.com/github/00BondViz/Using-Generative-Ai-to-Extract-Text-From-Image/blob/main/Using_GeminiPro_For_TextExtraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Start of by installing this library
# !pip install -q -U google-generativeai

# %%
# Importing the necessary packages
import pathlib
import textwrap

import google.generativeai as genai

# Used to securely store your API key
# Inside Userdata we can then store the api key
from google.colab import userdata

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# Using genrated API key
import os
os.environ['GOOGLE_API_KEY']='AIzaSyCNJK-ueiRWHxkjpifqyPJaIE3ZehqPP4s'

# %%
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# %%
import PIL.Image

img = PIL.Image.open('image-0079.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x720>

# %%
# Use the gemini-pro-vision model and pass the image to the model with generate_content.
model = genai.GenerativeModel('gemini-pro-vision')

# %%
# This part of the code, takes the image and gives out a response as what it can tell from the image it was fed
response = model.generate_content(img)

to_markdown(response.text)
# Out:
# >  | Name | Email | Company | Location |
# > |---|---|---|---|
# > | W. Kück | fh960@futterhaus.de | M. Pninschka oHG | Germany |
# > | Harry | harry@alphaplasticspvc.co.uk | Alpha Plastics | United Kingdom |
# > | Tony | t.sanger@hotmail.com | Y Sanger | United Kingdom |
# > | Wes | wes@chocochoc.co.uk | Choc on Choc | United Kingdom |
# > | Richard | richard.jameson@scss.uk.net | Software Consultancy Service Limited | United Kingdom |
# > | Nick | nick@knightscare.com | Knights Care | United Kingdom |
# > | Matt | matt@lab.co.uk | Lab Lateral | United Kingdom |
# > | David | david@interview-inc.com | Interview-Inc | United Kingdom |
# > | Irfan | irfan@bvrgroup.com | Islandbridge Capital Limited | United Kingdom |
# > | Russell | russell.elam@dp-sgroup.co.uk | DPS Group | United Kingdom |
# > | Leonid | lkurtsirtin@dp-sgroup.co.uk | DPS Group | United Kingdom |
# > | Hakim | hakim.bourahla@hotmail.fr | abwconcept | France |
# > | Karim | karim.hannahe@honeywell.com | Honeywell | France |
# > | Philippe | pchavaroche@escottelecom.com | ESCOT TELECOM | France |
# > | Denis | denis@gsea-design.com | GSEA DESIGN | France |
# > | Vincent | vincent.peyrouse@outlook.com | Learning Tree International | France |
# > | Andy | andy.heaton@enmodus.com | enModus Ltd | United Kingdom |
# > | PJ | pjremole@gmail.com | PJ Removals | United Kingdom |
# > | Moulaye | moulaye.labasse.traore@trak-communication.fr | TRAK - COMMUNICATION | France |

# %%
# The output as a response
to_markdown(response.text)
# Out:
# >  | Name | Email | Company | Location |
# > |---|---|---|---|
# > | W. Kück | fh960@futterhaus.de | M. Pninschka oHG | Germany |
# > | Harry | harry@alphaplasticspvc.co.uk | Alpha Plastics | United Kingdom |
# > | Tony | t.sanger@hotmail.com | Y Sanger | United Kingdom |
# > | Wes | wes@chocochoc.co.uk | Choc on Choc | United Kingdom |
# > | Richard | richard.jameson@scss.uk.net | Software Consultancy Service Limited | United Kingdom |
# > | Nick | nick@knightscare.com | Knights Care | United Kingdom |
# > | Matt | matt@lab.co.uk | Lab Lateral | United Kingdom |
# > | David | david@interview-inc.com | Interview-Inc | United Kingdom |
# > | Irfan | irfan@bvrgroup.com | Islandbridge Capital Limited | United Kingdom |
# > | Russell | russell.elam@dp-sgroup.co.uk | DPS Group | United Kingdom |
# > | Leonid | lkurtsirtin@dp-sgroup.co.uk | DPS Group | United Kingdom |
# > | Hakim | hakim.bourahla@hotmail.fr | abwconcept | France |
# > | Karim | karim.hannahe@honeywell.com | Honeywell | France |
# > | Philippe | pchavaroche@escottelecom.com | ESCOT TELECOM | France |
# > | Denis | denis@gsea-design.com | GSEA DESIGN | France |
# > | Vincent | vincent.peyrouse@outlook.com | Learning Tree International | France |
# > | Andy | andy.heaton@enmodus.com | enModus Ltd | United Kingdom |
# > | PJ | pjremole@gmail.com | PJ Removals | United Kingdom |
# > | Moulaye | moulaye.labasse.traore@trak-communication.fr | TRAK - COMMUNICATION | France |
